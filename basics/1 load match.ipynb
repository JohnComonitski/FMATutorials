# %% [markdown]
# # Load a Match
# Load a tracking data and event data into a Match object and get basic match data
#
# ---

# %% [markdown]
# **Change Directory**
#
# This block of code is only ran so that this notebook can use the FMA library.

# %%
from pathlib import Path
import sys
import os

cwd = os.getcwd()
os.chdir(cwd)

project_root = Path.cwd().parent
sys.path.append(str(project_root))

# %% [markdown]
# **Import FMA Library**

# %%
from FootballMatchAnalysis.objects.match import Match

# %% [markdown]
# **Event and Tracking Data**
#
# Sample tracking data has an ID of 1, 2, 3.

# %%
DATADIR = './../data'
game_id = 1

# %% [markdown]
# **Load Data into Match Object**
#
# This library takes an object oriented approach to match analysis and the Match object will serve as the jumping off point for most analysis. This object can be used to get specific event data, work with individual moments (frames) within the match and get other objects such as the Ball or Players.

# %%
match = Match(DATADIR, game_id)
